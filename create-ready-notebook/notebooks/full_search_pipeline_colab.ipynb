# %% [markdown]
# <a href="https://colab.research.google.com/github/AyazN/DLS-final-project/blob/feature/create-ready-notebook/notebooks/full_search_pipeline_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # AI Model Search — Full Search Pipeline
#
# This demonstration notebook connects the existing project artifacts into one end-to-end pipeline:
#
# **processed metadata → precomputed embeddings → FAISS → BM25 + dense retrieval → RRF → cross-encoder → evaluation**
#
# The notebook does not regenerate embeddings. It uses a low-memory mode by default and automatically caches the completed BM25 retriever on Google Drive before continuing. Colab High-RAM remains preferable for the full-quality configuration.

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1. Configuration
#
# If the integration branch has already been merged, change `REPO_BRANCH` to `develop` or `main`.
# The Drive configuration supports either an extracted encoder directory or the `.tar` archive produced by the earlier notebook.

# %%
from pathlib import Path

REPO_URL = "https://github.com/AyazN/DLS-final-project.git"
REPO_BRANCH = "feature/create-ready-notebook"
PROJECT_ROOT = Path("/content/DLS-final-project")

DRIVE_ROOT = Path("/content/drive/MyDrive/Inno/DLS/AISE")

MODEL_DIR_NAME = "sentence-transformers__all-MiniLM-L6-v2"
# To use BGE, switch to:
# MODEL_DIR_NAME = "BAAI__bge-small-en-v1.5"

DRIVE_EMBEDDING_CANDIDATES = [
    DRIVE_ROOT / "embeddings" / MODEL_DIR_NAME,
    DRIVE_ROOT / "data" / "processed" / "embeddings" / MODEL_DIR_NAME,
]
DRIVE_EMBEDDING_ARCHIVE_CANDIDATES = [
    DRIVE_ROOT / "embeddings" / "minilm_embeddings_600k.tar",
    DRIVE_ROOT / "minilm_embeddings_600k.tar",
]

LOCAL_EMBEDDING_DIR = (
    PROJECT_ROOT / "data" / "processed" / "embeddings" / MODEL_DIR_NAME
)
LOCAL_CLEAN_DATASET = PROJECT_ROOT / "data" / "processed" / "clean_dataset.parquet"

CLEAN_DATASET_CANDIDATES = [
    DRIVE_ROOT / "data" / "processed" / "clean_dataset.parquet",
    DRIVE_ROOT / "data" / "clean_dataset.parquet",
    DRIVE_ROOT / "clean_dataset.parquet",
]

INDEX_FILENAME = (
    "minilm_flat_ip.faiss"
    if MODEL_DIR_NAME.startswith("sentence-transformers")
    else "bge_small_flat_ip.faiss"
)
LOCAL_INDEX_PATH = PROJECT_ROOT / "data" / "indexes" / INDEX_FILENAME
DRIVE_INDEX_PATH = DRIVE_ROOT / "indices" / INDEX_FILENAME
DRIVE_INDEX_CANDIDATES = [
    DRIVE_INDEX_PATH,
    DRIVE_ROOT / "data" / "indexes" / INDEX_FILENAME,
    DRIVE_ROOT / "data" / "processed" / "indexes" / INDEX_FILENAME,
]

RELEVANCE_PATH = DRIVE_ROOT / "evaluation" / "relevance.csv"
DRIVE_RESULTS_DIR = DRIVE_ROOT / "results"
DRIVE_HF_CACHE = DRIVE_ROOT / "models" / "huggingface"
CROSS_ENCODER_NAME = "cross-encoder/ms-marco-MiniLM-L6-v2"

RETRIEVAL_TOP_K = 100
RERANK_TOP_K = 20

# Safe defaults for a free Colab runtime with about 12.7 GB system RAM.
LOW_MEMORY_MODE = True
BODY_MAX_CHARS_OVERRIDE = 200
BM25_CACHE_COMPRESSION = 3

# %% [markdown]
# ## 2. Repository and dependencies

# %%
import os
import subprocess
import sys

if (PROJECT_ROOT / ".git").exists():
    subprocess.run(
        ["git", "-C", str(PROJECT_ROOT), "fetch", "origin", "--prune"],
        check=True,
    )
    subprocess.run(
        ["git", "-C", str(PROJECT_ROOT), "checkout", REPO_BRANCH],
        check=True,
    )
    subprocess.run(
        ["git", "-C", str(PROJECT_ROOT), "pull", "--ff-only"],
        check=True,
    )
else:
    subprocess.run(
        [
            "git",
            "clone",
            "--branch",
            REPO_BRANCH,
            "--single-branch",
            REPO_URL,
            str(PROJECT_ROOT),
        ],
        check=True,
    )

os.chdir(PROJECT_ROOT)
sys.path.insert(0, str(PROJECT_ROOT / "src"))

repo_revision = subprocess.check_output(
    ["git", "-C", str(PROJECT_ROOT), "rev-parse", "--short", "HEAD"],
    text=True,
).strip()

print("Repository:", PROJECT_ROOT)
print("Branch:", REPO_BRANCH)
print("Revision:", repo_revision)
# Out:
# Repository: /content/DLS-final-project
# Branch: feature/create-ready-notebook
# Revision: 08a61da

# %%
# %pip install -q -r requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 78.4 MB/s eta 0:00:00

# %%
import inspect
import platform
from pathlib import Path

import aise
import numpy as np
import pandas as pd
import torch

from aise.contracts import EvaluationExample, Query
from aise.evaluation import RetrievalEvaluator
from aise.pipeline import SearchPipeline
from aise.retrieval import (
    BM25Retriever,
    CrossEncoderReranker,
    DenseRetriever,
    HybridRetriever,
    ReciprocalRankFusion,
)
from aise.search_index import (
    FaissFlatIndex,
    load_embedding_artifacts,
    load_search_documents,
)

expected_source_root = (PROJECT_ROOT / "src").resolve()
loaded_aise_path = Path(aise.__file__).resolve()
if expected_source_root not in loaded_aise_path.parents:
    raise RuntimeError(
        f"Loaded aise from {loaded_aise_path}, expected {expected_source_root}"
    )

required_document_loader_parameters = {"max_body_chars", "include_metadata"}
available_document_loader_parameters = set(
    inspect.signature(load_search_documents).parameters
)
missing_parameters = (
    required_document_loader_parameters - available_document_loader_parameters
)
if missing_parameters:
    raise RuntimeError(
        "The checked-out repository revision is too old for this notebook. "
        "Set REPO_BRANCH to feature/create-ready-notebook and rerun from the top. "
        f"Missing API parameters: {sorted(missing_parameters)}"
    )

print("AISE imports and notebook API compatibility verified")
print("Python:", platform.python_version())
print("NumPy:", np.__version__)
print("Torch device:", "cuda" if torch.cuda.is_available() else "cpu")
# Out:
# AISE imports and notebook API compatibility verified
# Python: 3.12.13
# NumPy: 2.0.2
# Torch device: cuda

# %% [markdown]
# ## 3. Prepare artifacts from Google Drive
#
# The embedding directory must contain `embeddings.npy`, `ids.npy`, `metadata.parquet`, `run_config.json`, `progress.json`, and `text_representation_samples.json`.

# %%
import shutil

REQUIRED_ARTIFACTS = (
    "embeddings.npy",
    "ids.npy",
    "metadata.parquet",
    "run_config.json",
    "progress.json",
    "text_representation_samples.json",
)


def has_artifacts(directory: Path) -> bool:
    return all((directory / name).exists() for name in REQUIRED_ARTIFACTS)


if not has_artifacts(LOCAL_EMBEDDING_DIR):
    LOCAL_EMBEDDING_DIR.mkdir(parents=True, exist_ok=True)
    source_embedding_dir = next(
        (path for path in DRIVE_EMBEDDING_CANDIDATES if has_artifacts(path)),
        None,
    )
    source_archive = next(
        (path for path in DRIVE_EMBEDDING_ARCHIVE_CANDIDATES if path.exists()),
        None,
    )

    if source_embedding_dir is not None:
        print("Copying embedding artifacts from:", source_embedding_dir)
        for name in REQUIRED_ARTIFACTS:
            shutil.copy2(
                source_embedding_dir / name,
                LOCAL_EMBEDDING_DIR / name,
            )
    elif source_archive is not None:
        print("Extracting embedding archive from:", source_archive)
        subprocess.run(
            [
                "tar",
                "-xf",
                str(source_archive),
                "-C",
                str(PROJECT_ROOT),
            ],
            check=True,
        )
    else:
        raise FileNotFoundError(
            "Embedding directory/archive was not found on Google Drive. "
            "Update DRIVE_EMBEDDING_CANDIDATES."
        )

if not LOCAL_CLEAN_DATASET.exists():
    source_dataset = next(
        (path for path in CLEAN_DATASET_CANDIDATES if path.exists()),
        None,
    )
    if source_dataset is None:
        raise FileNotFoundError(
            "clean_dataset.parquet was not found. Update CLEAN_DATASET_CANDIDATES."
        )
    LOCAL_CLEAN_DATASET.parent.mkdir(parents=True, exist_ok=True)
    print("Copying processed metadata from:", source_dataset)
    shutil.copy2(source_dataset, LOCAL_CLEAN_DATASET)

assert has_artifacts(LOCAL_EMBEDDING_DIR)
assert LOCAL_CLEAN_DATASET.exists()

print("Embedding directory:", LOCAL_EMBEDDING_DIR)
print("Processed metadata:", LOCAL_CLEAN_DATASET)
# Out:
# Extracting embedding archive from: /content/drive/MyDrive/Inno/DLS/AISE/embeddings/minilm_embeddings_600k.tar
# Copying processed metadata from: /content/drive/MyDrive/Inno/DLS/AISE/data/clean_dataset.parquet
# Embedding directory: /content/DLS-final-project/data/processed/embeddings/sentence-transformers__all-MiniLM-L6-v2
# Processed metadata: /content/DLS-final-project/data/processed/clean_dataset.parquet

# %% [markdown]
# ## 4. Load and validate embedding artifacts

# %%
from aise.search_index import load_embedding_artifacts

artifacts = load_embedding_artifacts(
    LOCAL_EMBEDDING_DIR,
    mmap_embeddings=True,
    expected_dim=384,
)

print("Shape:", artifacts.embeddings.shape)
print("Dtype:", artifacts.embeddings.dtype)
print("Encoder:", artifacts.model_name)
print("Normalized:", artifacts.normalized)
print("Metadata columns:", artifacts.metadata.columns.tolist())

ENCODER_MODEL_NAME = artifacts.model_name
NORMALIZE_QUERY_EMBEDDINGS = artifacts.normalized
ARTIFACT_ROW_COUNT = artifacts.embeddings.shape[0]
ARTIFACT_DIM = artifacts.embeddings.shape[1]
BODY_MAX_CHARS = (
    BODY_MAX_CHARS_OVERRIDE
    if BODY_MAX_CHARS_OVERRIDE is not None
    else int(artifacts.run_config.get("max_model_card_chars", 2500))
)

print("Low-memory mode:", LOW_MEMORY_MODE)
print("Maximum body characters used by retrieval:", BODY_MAX_CHARS)

assert artifacts.embeddings.shape == (600_000, 384)
assert artifacts.embeddings.dtype == np.float32
assert artifacts.normalized is True
# Out:
# Shape: (600000, 384)
# Dtype: float32
# Encoder: sentence-transformers/all-MiniLM-L6-v2
# Normalized: True
# Metadata columns: ['embedding_row', 'model_id', 'likes', 'downloads', 'tags', 'pipeline_tag', 'library_name', 'createdAt', 'languages', 'text_length_chars']
# Low-memory mode: True
# Maximum body characters used by retrieval: 200

# %% [markdown]
# ## 5. Build or restore the BM25 retriever
#
# The BM25 cache is written to Google Drive before the notebook continues. If the runtime disconnects later, the next run restores BM25 instead of rebuilding it. Low-memory mode keeps document bodies but omits duplicated artifact metadata from each in-memory document.

# %%
# %%time

import gc
import joblib
import psutil

from aise.retrieval import BM25Retriever
from aise.search_index import load_search_documents

BM25_CACHE_PATH = (
    DRIVE_ROOT
    / "indices"
    / f"bm25_600k_body{BODY_MAX_CHARS}.joblib"
)
LOCAL_BM25_CACHE_PATH = Path(
    f"/content/bm25_600k_body{BODY_MAX_CHARS}.joblib"
)
BM25_CACHE_PATH.parent.mkdir(parents=True, exist_ok=True)


def print_system_memory(label: str) -> None:
    memory = psutil.virtual_memory()
    print(
        f"{label}: used={memory.used / 1024**3:.1f} GB, "
        f"available={memory.available / 1024**3:.1f} GB"
    )


if BM25_CACHE_PATH.exists():
    print("Copying cached BM25 retriever from Drive:", BM25_CACHE_PATH)
    del artifacts
    gc.collect()
    shutil.copy2(BM25_CACHE_PATH, LOCAL_BM25_CACHE_PATH)
    bundle = joblib.load(LOCAL_BM25_CACHE_PATH)
    LOCAL_BM25_CACHE_PATH.unlink(missing_ok=True)

    if bundle.get("document_count") != ARTIFACT_ROW_COUNT:
        raise ValueError("Cached BM25 document count does not match the artifacts")
    if bundle.get("body_max_chars") != BODY_MAX_CHARS:
        raise ValueError("Cached BM25 body limit does not match the configuration")

    bm25 = bundle["retriever"]
    documents = bm25.documents
    del bundle
    gc.collect()
else:
    print("No BM25 cache found; creating aligned search documents...")
    documents = load_search_documents(
        artifacts,
        processed_metadata_path=LOCAL_CLEAN_DATASET,
        max_body_chars=BODY_MAX_CHARS,
        include_metadata=not LOW_MEMORY_MODE,
    )
    assert len(documents) == ARTIFACT_ROW_COUNT

    print("Documents:", len(documents))
    print("Example:", documents[0].model_id, documents[0].title)
    print("Body preview:", documents[0].body[:300])

    del artifacts
    gc.collect()
    print_system_memory("Before BM25 build")

    print("Building BM25 over the complete document collection...")
    bm25 = BM25Retriever(documents)
    print("BM25 build completed")
    print_system_memory("After BM25 build")

    bundle = {
        "format_version": 1,
        "retriever": bm25,
        "document_count": len(documents),
        "body_max_chars": BODY_MAX_CHARS,
        "low_memory_mode": LOW_MEMORY_MODE,
    }

    print("Serializing BM25 cache locally...")
    joblib.dump(
        bundle,
        LOCAL_BM25_CACHE_PATH,
        compress=BM25_CACHE_COMPRESSION,
    )
    cache_size_gb = LOCAL_BM25_CACHE_PATH.stat().st_size / 1024**3
    print(f"Local BM25 cache size: {cache_size_gb:.2f} GB")

    temporary_drive_path = BM25_CACHE_PATH.with_suffix(".joblib.tmp")
    print("Copying BM25 cache to Google Drive...")
    shutil.copy2(LOCAL_BM25_CACHE_PATH, temporary_drive_path)
    temporary_drive_path.replace(BM25_CACHE_PATH)
    LOCAL_BM25_CACHE_PATH.unlink(missing_ok=True)

    print("BM25 cache saved successfully:", BM25_CACHE_PATH)
    del bundle
    gc.collect()

assert len(documents) == ARTIFACT_ROW_COUNT
print("BM25 is ready for", len(documents), "documents")
print_system_memory("BM25 stage completed")
# Out:
# No BM25 cache found; creating aligned search documents...
# Documents: 600000
# Example: Falconsai/nsfw_image_detection Falconsai/nsfw_image_detection
# Body preview: license: apache 2.0
# pipeline_tag: image classification
#
#  Model Card: Fine Tuned Vision Transformer (ViT) for NSFW Image Classification
#
#  Model Description
#
# The Fine Tuned Vision Transformer (ViT) is
# Before BM25 build: used=3.7 GB, available=8.6 GB
# Building BM25 over the complete document collection...
# BM25 build completed
# After BM25 build: used=5.2 GB, available=7.2 GB
# Serializing BM25 cache locally...
# Local BM25 cache size: 0.11 GB
# Copying BM25 cache to Google Drive...
# BM25 cache saved successfully: /content/drive/MyDrive/Inno/DLS/AISE/indices/bm25_600k_body200.joblib
# BM25 is ready for 600000 documents
# BM25 stage completed: used=6.3 GB, available=6.1 GB
# CPU times: user 3min 14s, sys: 6.87 s, total: 3min 21s
# Wall time: 3min 25s

# %% [markdown]
# ## 6. FAISS index
#
# The vectors are already L2-normalized, so `IndexFlatIP` provides cosine-equivalent ranking. The notebook first tries to load a cached index from Drive. If no index exists, it builds one from the precomputed embeddings and saves it for future runs.

# %%
from aise.search_index import FaissFlatIndex, load_embedding_artifacts

import gc

# Reload the lightweight artifact handles after the memory-intensive BM25 stage.
artifacts = load_embedding_artifacts(
    LOCAL_EMBEDDING_DIR,
    mmap_embeddings=True,
    expected_dim=ARTIFACT_DIM,
)
artifact_ids = artifacts.ids
dense_metadata = None if LOW_MEMORY_MODE else artifacts.metadata

LOCAL_INDEX_PATH.parent.mkdir(parents=True, exist_ok=True)
DRIVE_INDEX_PATH.parent.mkdir(parents=True, exist_ok=True)

source_index = next(
    (path for path in DRIVE_INDEX_CANDIDATES if path.exists()),
    None,
)
if not LOCAL_INDEX_PATH.exists() and source_index is not None:
    print("Copying FAISS index from:", source_index)
    shutil.copy2(source_index, LOCAL_INDEX_PATH)

vector_index = FaissFlatIndex(
    dim=ARTIFACT_DIM,
    metric="inner_product",
)

if LOCAL_INDEX_PATH.exists():
    print("Loading FAISS index:", LOCAL_INDEX_PATH)
    vector_index.load(LOCAL_INDEX_PATH)
else:
    print("Building FAISS index from precomputed embeddings...")
    vector_index.build(artifacts.embeddings)
    vector_index.save(LOCAL_INDEX_PATH)
    shutil.copy2(LOCAL_INDEX_PATH, DRIVE_INDEX_PATH)
    print("Saved index to Drive:", DRIVE_INDEX_PATH)

assert vector_index.ntotal == ARTIFACT_ROW_COUNT
assert vector_index.dim == ARTIFACT_DIM

print("Vectors indexed:", vector_index.ntotal)
print("Metric:", vector_index.metric)
print("Higher is better:", vector_index.higher_is_better)

del artifacts
gc.collect()
print_system_memory("FAISS stage completed")
# Out:
# Copying FAISS index from: /content/drive/MyDrive/Inno/DLS/AISE/indices/minilm_flat_ip.faiss
# Loading FAISS index: /content/DLS-final-project/data/indexes/minilm_flat_ip.faiss
# Vectors indexed: 600000
# Metric: inner_product
# Higher is better: True
# FAISS stage completed: used=7.3 GB, available=5.1 GB

# %% [markdown]
# ## 7. Encoder, dense retrieval, and RRF fusion

# %%
import torch

import os

os.environ["HF_HUB_DISABLE_XET"] = "1"

from sentence_transformers import SentenceTransformer

DRIVE_HF_CACHE.mkdir(parents=True, exist_ok=True)
encoder_device = "cuda" if torch.cuda.is_available() else "cpu"
encoder = SentenceTransformer(
    ENCODER_MODEL_NAME,
    device=encoder_device,
    cache_folder=str(DRIVE_HF_CACHE),
)

print("Loaded encoder:", ENCODER_MODEL_NAME)
print("Encoder device:", encoder_device)
print("Persistent Hugging Face cache:", DRIVE_HF_CACHE)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Loaded encoder: sentence-transformers/all-MiniLM-L6-v2
# Encoder device: cuda
# Persistent Hugging Face cache: /content/drive/MyDrive/Inno/DLS/AISE/models/huggingface

# %%
from aise.retrieval import (
    DenseRetriever,
    HybridRetriever,
    ReciprocalRankFusion,
)

dense = DenseRetriever(
    index=vector_index,
    documents=documents,
    model=encoder,
    encoder_name=ENCODER_MODEL_NAME,
    ids=artifact_ids,
    metadata=dense_metadata,
    normalize_embeddings=NORMALIZE_QUERY_EMBEDDINGS,
)

hybrid = HybridRetriever(
    bm25=bm25,
    dense=dense,
    fusion=ReciprocalRankFusion(k=60),
)

# %%
import pandas as pd

from aise.contracts import Query

def results_frame(results):
    return pd.DataFrame(
        [
            {
                "rank": result.rank,
                "doc_id": result.doc_id,
                "model_id": result.model_id,
                "title": result.title,
                "score": result.score,
                "snippet": result.snippet[:240],
            }
            for result in results
        ]
    )


DRIVE_RESULTS_DIR.mkdir(parents=True, exist_ok=True)
demo_query = Query(
    text="football video analysis model",
    top_k=RETRIEVAL_TOP_K,
)

bm25_demo_results = bm25.search(demo_query)
dense_demo_results = dense.search(demo_query)
hybrid_results = hybrid.search(demo_query)

result_tables = {
    "bm25_demo_results.csv": results_frame(bm25_demo_results),
    "dense_demo_results.csv": results_frame(dense_demo_results),
    "hybrid_rrf_demo_results.csv": results_frame(hybrid_results),
}
for filename, table in result_tables.items():
    table.to_csv(DRIVE_RESULTS_DIR / filename, index=False)

print("Saved BM25, dense, and hybrid result tables to:", DRIVE_RESULTS_DIR)
display(result_tables["hybrid_rrf_demo_results.csv"].head(20))
# Out:
# Saved BM25, dense, and hybrid result tables to: /content/drive/MyDrive/Inno/DLS/AISE/results
#     rank                                             doc_id  \
# 0      1                  Ayushkm10/Football_video_analyser
# 1      2  mrp1mple/Llama-3.2-3B-Instruct-Football_Match_...
# 2      3  RichardErkhov/Sassi-Helmi_-_Qwen2_finetuning_m...
# 3      4  RichardErkhov/mrp1mple_-_Llama-3.2-3B-Instruct...
# 4      5     EdBianchi/ProfVLMv2-Exo3-PATS-DualLoRA-16heads
# 5      6           model-hub/stable-video-diffusion-img2vid
# 6      7        model-hub/stable-video-diffusion-img2vid-xt
# 7      8                 vdo/stable-video-diffusion-img2vid
# 8      9          riccardopresti99/topic_modelling_football
# 9     10                                       joshhhyyy/ai
# 10    11              vdo/stable-video-diffusion-img2vid-xt
# 11    12         stabilityai/stable-video-diffusion-img2vid
# 12    13                          OmarhAhmed/ai-padel-coach
# 13    14                            forrreal/football_model
# 14    15        lzyvegetable/stable-video-diffusion-img2vid
# 15    16                                sportsvision/SV3.3B
# 16    17                               Lightricks/LTX-Video
# 17    18               falahmanalodi/Football-Commentary-EE
# 18    19     IsaacMwesigwa/footballer-recognition-gray-nobg
# 19    20                                      NullVoider/V1
#
#                                              model_id  \
# 0                   Ayushkm10/Football_video_analyser
# 1   mrp1mple/Llama-3.2-3B-Instruct-Football_Match_...
# 2   RichardErkhov/Sassi-Helmi_-_Qwen2_finetuning_m...
# 3   RichardErkhov/mrp1mple_-_Llama-3.2-3B-Instruct...
# 4      EdBianchi/ProfVLMv2-Exo3-PATS-DualLoRA-16heads
# 5            model-hub/stable-video-diffusion-img2vid
# 6         model-hub/stable-video-diffusion-img2vid-xt
# 7                  vdo/stable-video-diffusion-img2vid
# 8           riccardopresti99/topic_modelling_football
# 9                                        joshhhyyy/ai
# 10              vdo/stable-video-diffusion-img2vid-xt
# 11         stabilityai/stable-video-diffusion-img2vid
# 12                          OmarhAhmed/ai-padel-coach
# 13                            forrreal/football_model
# 14        lzyvegetable/stable-video-diffusion-img2vid
# 15                                sportsvision/SV3.3B
# 16                               Lightricks/LTX-Video
# 17               falahmanalodi/Football-Commentary-EE
# 18     IsaacMwesigwa/footballer-recognition-gray-nobg
# 19                                      NullVoider/V1
#
#                                                 title     score  \
# 0                   Ayushkm10/Football_video_analyser  0.032522
# 1   mrp1mple/Llama-3.2-3B-Instruct-Football_Match_...  0.029139
# 2   RichardErkhov/Sassi-Helmi_-_Qwen2_finetuning_m...  0.028860
# 3   RichardErkhov/mrp1mple_-_Llama-3.2-3B-Instruct...  0.025333
# 4      EdBianchi/ProfVLMv2-Exo3-PATS-DualLoRA-16heads  0.024321
# 5            model-hub/stable-video-diffusion-img2vid  0.023632
# 6         model-hub/stable-video-diffusion-img2vid-xt  0.020278
# 7                  vdo/stable-video-diffusion-img2vid  0.019638
# 8           riccardopresti99/topic_modelling_football  0.018558
# 9                                        joshhhyyy/ai  0.018194
# 10              vdo/stable-video-diffusion-img2vid-xt  0.016885
# 11         stabilityai/stable-video-diffusion-img2vid  0.016506
# 12                          OmarhAhmed/ai-padel-coach  0.016393
# 13                            forrreal/football_model  0.016129
# 14        lzyvegetable/stable-video-diffusion-img2vid  0.015890
# 15                                sportsvision/SV3.3B  0.015873
# 16                               Lightricks/LTX-Video  0.015625
# 17               falahmanalodi/Football-Commentary-EE  0.015385
# 18     IsaacMwesigwa/footballer-recognition-gray-nobg  0.015385
# 19                                      NullVoider/V1  0.015152
#
#                                               snippet
# 0   {}\n \nFootball Video Analyser\n\nProject host...
# 1   library_name: transformers\ntags: []\n \n\n Ll...
# 2   {}\n \nQuantization made by Richard Erkhov.\n\...
# 3   {}\n \nQuantization made by Richard Erkhov.\n\...
# 4   license: apache 2.0\nbase_model:\n HuggingFace...
# 5   pipeline_tag: image to video\nlicense: other\n...
# 6   pipeline_tag: image to video\nlicense: other\n...
# 7   {}\n \n\n Stable Video Diffusion Image to Vide...
# 8   tags:\n bertopic\nlibrary_name: bertopic\npipe...
# 9   pipeline_tag: image to video\nlicense: other\n...
# 10  {}\n \n\n Stable Video Diffusion Image to Vide...
# 11  pipeline_tag: image to video\nlicense: other\n...
# 12  {}\n \n AI padel coach\n\nThis project analyze...
# 13                                       license: mit
# 14  pipeline_tag: image to video\nlicense: other\n...
# 15  language: en\nlicense: cc by nc 4.0\ntags:\n v...
# 16  tags:\n ltx video\n image to video\npinned: tr...
# 17  license: mit\nlanguage:\n en\nmetrics:\n accur...
# 18  tags:\n autotrain\n image classification\nwidg...
# 19  language:\n en\nbase_model:\n tencent/HunyuanV...

# %% [markdown]
# ## 8. Cross-encoder reranking

# %%
from sentence_transformers import CrossEncoder

from aise.retrieval import CrossEncoderReranker

cross_encoder = CrossEncoder(
    CROSS_ENCODER_NAME,
    device=encoder_device,
    cache_folder=str(DRIVE_HF_CACHE),
)
reranker = CrossEncoderReranker(
    cross_encoder,
    top_k=RERANK_TOP_K,
)

reranked_results = reranker.rank(demo_query, hybrid_results)
reranked_table = results_frame(reranked_results)
reranked_table.to_csv(
    DRIVE_RESULTS_DIR / "cross_encoder_reranked_demo_results.csv",
    index=False,
)
print("Saved reranked results to:", DRIVE_RESULTS_DIR)
display(reranked_table)
# Out:
# config.json:   0%|          | 0.00/794 [00:00<?, ?B/s]
# WARNING:sentence_transformers.util.decorators:The Transformer `cache_dir` argument is deprecated. Please pass `cache_dir` via `model_kwargs`, `processor_kwargs`, and/or `config_kwargs` instead.
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# Saved reranked results to: /content/drive/MyDrive/Inno/DLS/AISE/results
#     rank                                             doc_id  \
# 0      1                  Ayushkm10/Football_video_analyser
# 1      2                          OmarhAhmed/ai-padel-coach
# 2      3  RichardErkhov/Sassi-Helmi_-_Qwen2_finetuning_m...
# 3      4  RichardErkhov/mrp1mple_-_Llama-3.2-3B-Instruct...
# 4      5  mrp1mple/Llama-3.2-3B-Instruct-Football_Match_...
# 5      6  thanhkaist/blip2-opt-2.7b-peft-football-captio...
# 6      7          riccardopresti99/topic_modelling_football
# 7      8     EdBianchi/ProfVLMv2-Exo3-PATS-DualLoRA-16heads
# 8      9                            forrreal/football_model
# 9     10                        keremberke/yolov5s-football
# 10    11                        keremberke/yolov5m-football
# 11    12                        keremberke/yolov5n-football
# 12    13               falahmanalodi/Football-Commentary-EE
# 13    14                      Lin-Chen/ShareCaptioner-Video
# 14    15                           MISHANM/video_generation
# 15    16    svjack/Petio_Ball_wan_2_1_1_3_B_text2video_lora
# 16    17             IsaacMwesigwa/footballer-recognition-3
# 17    18                     google/videoprism-base-f16r288
# 18    19             IsaacMwesigwa/footballer-recognition-2
# 19    20       CoreyMorris/poca-SoccerTwos-football-is-life
#
#                                              model_id  \
# 0                   Ayushkm10/Football_video_analyser
# 1                           OmarhAhmed/ai-padel-coach
# 2   RichardErkhov/Sassi-Helmi_-_Qwen2_finetuning_m...
# 3   RichardErkhov/mrp1mple_-_Llama-3.2-3B-Instruct...
# 4   mrp1mple/Llama-3.2-3B-Instruct-Football_Match_...
# 5   thanhkaist/blip2-opt-2.7b-peft-football-captio...
# 6           riccardopresti99/topic_modelling_football
# 7      EdBianchi/ProfVLMv2-Exo3-PATS-DualLoRA-16heads
# 8                             forrreal/football_model
# 9                         keremberke/yolov5s-football
# 10                        keremberke/yolov5m-football
# 11                        keremberke/yolov5n-football
# 12               falahmanalodi/Football-Commentary-EE
# 13                      Lin-Chen/ShareCaptioner-Video
# 14                           MISHANM/video_generation
# 15    svjack/Petio_Ball_wan_2_1_1_3_B_text2video_lora
# 16             IsaacMwesigwa/footballer-recognition-3
# 17                     google/videoprism-base-f16r288
# 18             IsaacMwesigwa/footballer-recognition-2
# 19       CoreyMorris/poca-SoccerTwos-football-is-life
#
#                                                 title     score  \
# 0                   Ayushkm10/Football_video_analyser  7.694456
# 1                           OmarhAhmed/ai-padel-coach  1.622279
# 2   RichardErkhov/Sassi-Helmi_-_Qwen2_finetuning_m...  0.041208
# 3   RichardErkhov/mrp1mple_-_Llama-3.2-3B-Instruct... -0.143834
# 4   mrp1mple/Llama-3.2-3B-Instruct-Football_Match_... -0.968521
# 5   thanhkaist/blip2-opt-2.7b-peft-football-captio... -1.239958
# 6           riccardopresti99/topic_modelling_football -1.257315
# 7      EdBianchi/ProfVLMv2-Exo3-PATS-DualLoRA-16heads -1.261402
# 8                             forrreal/football_model -1.871982
# 9                         keremberke/yolov5s-football -2.097505
# 10                        keremberke/yolov5m-football -2.197436
# 11                        keremberke/yolov5n-football -2.204644
# 12               falahmanalodi/Football-Commentary-EE -3.893218
# 13                      Lin-Chen/ShareCaptioner-Video -4.203253
# 14                           MISHANM/video_generation -5.413181
# 15    svjack/Petio_Ball_wan_2_1_1_3_B_text2video_lora -5.862842
# 16             IsaacMwesigwa/footballer-recognition-3 -5.902102
# 17                     google/videoprism-base-f16r288 -5.943038
# 18             IsaacMwesigwa/footballer-recognition-2 -5.943814
# 19       CoreyMorris/poca-SoccerTwos-football-is-life -5.958470
#
#                                               snippet
# 0   {}\n \nFootball Video Analyser\n\nProject host...
# 1   {}\n \n AI padel coach\n\nThis project analyze...
# 2   {}\n \nQuantization made by Richard Erkhov.\n\...
# 3   {}\n \nQuantization made by Richard Erkhov.\n\...
# 4   library_name: transformers\ntags: []\n \n\n Ll...
# 5   library_name: peft\nbase_model: ybelkada/blip2...
# 6   tags:\n bertopic\nlibrary_name: bertopic\npipe...
# 7   license: apache 2.0\nbase_model:\n HuggingFace...
# 8                                        license: mit
# 9   tags:\n yolov5\n yolo\n vision\n object detect...
# 10  tags:\n yolov5\n yolo\n vision\n object detect...
# 11  tags:\n yolov5\n yolo\n vision\n object detect...
# 12  license: mit\nlanguage:\n en\nmetrics:\n accur...
# 13  inference: false\ndatasets:\n ShareGPT4Video/S...
# 14  library_name: diffusers\n \n \n \n MISHANM/vid...
# 15  {}\n \n Petio_Ball Text to Video Generation\n\...
# 16  tags:\n autotrain\n image classification\nwidg...
# 17  license: apache 2.0\ntags:\n video classificat...
# 18  tags:\n autotrain\n image classification\nwidg...
# 19  tags:\n unity ml agents\n ml agents\n deep rei...

# %%
from aise.contracts import Query
from aise.pipeline import SearchPipeline

search_pipeline = SearchPipeline(
    retriever=hybrid,
    ranker=reranker,
)


def search_models(text: str, candidate_k: int = RETRIEVAL_TOP_K):
    query = Query(text=text, top_k=candidate_k)
    return results_frame(search_pipeline.search(query))


pipeline_demo_table = search_models("small multilingual text classification model")
pipeline_demo_table.to_csv(
    DRIVE_RESULTS_DIR / "end_to_end_pipeline_demo_results.csv",
    index=False,
)
display(pipeline_demo_table)
# Out:
#     rank                                             doc_id  \
# 0      1                               layperson99/LaymanT5
# 1      2            AventIQ-AI/Multilingual_Text_Translator
# 2      3              s-nlp/E5-EverGreen-Multilingual-Small
# 3      4             microsoft/Multilingual-MiniLM-L12-H384
# 4      5         hmbyt5-preliminary/flair-hipe-2022-ajmc-fr
# 5      6         hmbyt5-preliminary/flair-hipe-2022-ajmc-de
# 6      7      hmbyt5-preliminary/flair-hipe-2022-newseye-de
# 7      8      hmbyt5-preliminary/flair-hipe-2022-newseye-fr
# 8      9     hmbyt5-preliminary/flair-hipe-2022-hipe2020-de
# 9     10                  hmbyt5-preliminary/flair-icdar-fr
# 10    11   hmbyt5-preliminary/flair-hipe-2022-topres19th-en
# 11    12            Darsala/intfloat-multilingual-finetuned
# 12    13        srikarvar/multilingual-e5-small-pairclass-4
# 13    14        srikarvar/multilingual-e5-small-pairclass-1
# 14    15              nvidia/multilingual-domain-classifier
# 15    16              kaixkhazaki/multilingual-e5-doclaynet
# 16    17                          castorini/afriberta_small
# 17    18  davidschulte/ESM_murodbek__uz-text-classificat...
# 18    19                 jimfhahn/bert-multilingual-uncased
# 19    20  thegenerativegeneration/stay_or_go_conversatio...
#
#                                              model_id  \
# 0                                layperson99/LaymanT5
# 1             AventIQ-AI/Multilingual_Text_Translator
# 2               s-nlp/E5-EverGreen-Multilingual-Small
# 3              microsoft/Multilingual-MiniLM-L12-H384
# 4          hmbyt5-preliminary/flair-hipe-2022-ajmc-fr
# 5          hmbyt5-preliminary/flair-hipe-2022-ajmc-de
# 6       hmbyt5-preliminary/flair-hipe-2022-newseye-de
# 7       hmbyt5-preliminary/flair-hipe-2022-newseye-fr
# 8      hmbyt5-preliminary/flair-hipe-2022-hipe2020-de
# 9                   hmbyt5-preliminary/flair-icdar-fr
# 10   hmbyt5-preliminary/flair-hipe-2022-topres19th-en
# 11            Darsala/intfloat-multilingual-finetuned
# 12        srikarvar/multilingual-e5-small-pairclass-4
# 13        srikarvar/multilingual-e5-small-pairclass-1
# 14              nvidia/multilingual-domain-classifier
# 15              kaixkhazaki/multilingual-e5-doclaynet
# 16                          castorini/afriberta_small
# 17  davidschulte/ESM_murodbek__uz-text-classificat...
# 18                 jimfhahn/bert-multilingual-uncased
# 19  thegenerativegeneration/stay_or_go_conversatio...
#
#                                                 title     score  \
# 0                                layperson99/LaymanT5  6.049663
# 1             AventIQ-AI/Multilingual_Text_Translator  5.546211
# 2               s-nlp/E5-EverGreen-Multilingual-Small  5.525352
# 3              microsoft/Multilingual-MiniLM-L12-H384  5.308989
# 4          hmbyt5-preliminary/flair-hipe-2022-ajmc-fr  4.607910
# 5          hmbyt5-preliminary/flair-hipe-2022-ajmc-de  4.532417
# 6       hmbyt5-preliminary/flair-hipe-2022-newseye-de  4.482616
# 7       hmbyt5-preliminary/flair-hipe-2022-newseye-fr  4.400193
# 8      hmbyt5-preliminary/flair-hipe-2022-hipe2020-de  4.391705
# 9                   hmbyt5-preliminary/flair-icdar-fr  4.363586
# 10   hmbyt5-preliminary/flair-hipe-2022-topres19th-en  4.337928
# 11            Darsala/intfloat-multilingual-finetuned  4.295608
# 12        srikarvar/multilingual-e5-small-pairclass-4  4.191218
# 13        srikarvar/multilingual-e5-small-pairclass-1  4.185438
# 14              nvidia/multilingual-domain-classifier  4.146561
# 15              kaixkhazaki/multilingual-e5-doclaynet  3.696116
# 16                          castorini/afriberta_small  3.473757
# 17  davidschulte/ESM_murodbek__uz-text-classificat...  3.357276
# 18                 jimfhahn/bert-multilingual-uncased  3.309776
# 19  thegenerativegeneration/stay_or_go_conversatio...  3.308583
#
#                                               snippet
# 0   {}\n \n\n Flan T5 Small Text Classification Mo...
# 1   {}\n \n 🌐 T5 Based Multilingual Text Translato...
# 2   library_name: transformers\ndatasets:\n s nlp/...
# 3   language:\n multilingual\n en\n ar\n bg\n de\n...
# 4   language: fr\nlicense: mit\ntags:\n flair\n to...
# 5   language: de\nlicense: mit\ntags:\n flair\n to...
# 6   language: de\nlicense: mit\ntags:\n flair\n to...
# 7   language: fr\nlicense: mit\ntags:\n flair\n to...
# 8   language: de\nlicense: mit\ntags:\n flair\n to...
# 9   language: fr\nlicense: mit\ntags:\n flair\n to...
# 10  language: en\nlicense: mit\ntags:\n flair\n to...
# 11  language:\n ka\nbase_model: intfloat/multiling...
# 12  base_model: intfloat/multilingual e5 small\nda...
# 13  base_model: intfloat/multilingual e5 small\nda...
# 14  tags:\n model_hub_mixin\n pytorch_model_hub_mi...
# 15  language: multilingual\ntags:\n document class...
# 16  {}\n \nHugging Face's logo\n \nlanguage: \n om...
# 17  base_model: bert base multilingual uncased\nda...
# 18  tags:\n autotrain\n text classification\nbase_...
# 19  library_name: setfit\ntags:\n setfit\n sentenc...

# %% [markdown]
# ## 9. Evaluation
#
# Evaluation uses real relevance labels only. The `relevance.csv` file must contain:
#
# - `query`: query text;
# - `relevant_model_ids`: either a JSON array of model IDs or IDs separated by `|` or `;`.
#
# If the file is missing, evaluation is skipped without generating artificial labels.

# %%
import ast
import json

from aise.contracts import EvaluationExample, Query


def parse_relevant_ids(value) -> tuple[str, ...]:
    if isinstance(value, (list, tuple, set)):
        return tuple(str(item).strip() for item in value if str(item).strip())

    text = str(value).strip()
    if not text or text.lower() in {"nan", "none", "null", "[]"}:
        return ()

    if text.startswith("["):
        try:
            return parse_relevant_ids(json.loads(text))
        except json.JSONDecodeError:
            return parse_relevant_ids(ast.literal_eval(text))

    separator = "|" if "|" in text else ";"
    return tuple(part.strip() for part in text.split(separator) if part.strip())


evaluation_examples: list[EvaluationExample] = []

if RELEVANCE_PATH.exists():
    relevance = pd.read_csv(RELEVANCE_PATH)
    required_columns = {"query", "relevant_model_ids"}
    missing = required_columns.difference(relevance.columns)
    if missing:
        raise ValueError(f"Missing relevance columns: {sorted(missing)}")

    evaluation_examples = [
        EvaluationExample(
            query=Query(str(row["query"]), top_k=RETRIEVAL_TOP_K),
            relevant_model_ids=parse_relevant_ids(row["relevant_model_ids"]),
        )
        for _, row in relevance.iterrows()
    ]
    print("Evaluation queries:", len(evaluation_examples))
else:
    print("Evaluation skipped; file not found:", RELEVANCE_PATH)
# Out:
# Evaluation skipped; file not found: /content/drive/MyDrive/Inno/DLS/AISE/evaluation/relevance.csv

# %%
from aise.evaluation import RetrievalEvaluator

if evaluation_examples:
    systems = {
        "bm25": bm25,
        "dense": dense,
        "hybrid_rrf": hybrid,
        "hybrid_rrf_cross_encoder": search_pipeline,
    }

    reports = {}
    for system_name, system in systems.items():
        evaluator = RetrievalEvaluator(
            metric_k_values=(1, 5, 10, 20),
            top_k=RETRIEVAL_TOP_K,
        )
        reports[system_name] = evaluator.evaluate(
            evaluation_examples,
            system,
        )

    metrics_table = pd.DataFrame(
        {
            name: dict(report.metrics)
            for name, report in reports.items()
        }
    ).T

    display(metrics_table)

# %%
DRIVE_RESULTS_DIR.mkdir(parents=True, exist_ok=True)

if evaluation_examples:
    report_path = DRIVE_RESULTS_DIR / "full_search_pipeline_metrics.json"
    with report_path.open("w", encoding="utf-8") as stream:
        json.dump(
            {
                name: {
                    "metrics": dict(report.metrics),
                    "details": dict(report.details),
                }
                for name, report in reports.items()
            },
            stream,
            ensure_ascii=False,
            indent=2,
        )
    print("Saved evaluation report:", report_path)

run_summary = {
    "status": "complete",
    "encoder_model": ENCODER_MODEL_NAME,
    "cross_encoder_model": CROSS_ENCODER_NAME,
    "document_count": len(documents),
    "embedding_dimension": ARTIFACT_DIM,
    "body_max_chars": BODY_MAX_CHARS,
    "low_memory_mode": LOW_MEMORY_MODE,
    "retrieval_top_k": RETRIEVAL_TOP_K,
    "rerank_top_k": RERANK_TOP_K,
    "bm25_cache": str(BM25_CACHE_PATH),
    "faiss_index": str(DRIVE_INDEX_PATH),
    "evaluation_queries": len(evaluation_examples),
    "saved_result_files": sorted(
        path.name for path in DRIVE_RESULTS_DIR.glob("*.csv")
    ),
}
summary_path = DRIVE_RESULTS_DIR / "full_search_pipeline_run_summary.json"
with summary_path.open("w", encoding="utf-8") as stream:
    json.dump(run_summary, stream, ensure_ascii=False, indent=2)

print("Saved run summary:", summary_path)
print("The complete pipeline run finished successfully")
# Out:
# Saved run summary: /content/drive/MyDrive/Inno/DLS/AISE/results/full_search_pipeline_run_summary.json
# The complete pipeline run finished successfully

# %% [markdown]
# ## Ready for demonstration
#
# The notebook persists all expensive reusable artifacts and presentation outputs:
#
# - BM25 cache;
# - FAISS index;
# - Hugging Face encoder and cross-encoder cache;
# - BM25, dense, hybrid, reranked, and end-to-end demo CSV files;
# - evaluation metrics when real labels are available;
# - a final run summary that is written only after the complete pipeline succeeds.
